# %% [markdown]
# ## Working Title: Baseball Analysis, bunts vs HR over a century

# %% [markdown]
# #### Authored by Ben Mescher, for submission "P2-Investigate a Dataset" as part of Udacity's Data Analyst Nanodegree program

# %% [markdown]
# ##### Submission History:
# *2015-Dec-24: Initial Udacity submit and upload to GitHub (https://github.com/benmesch/DataAnalysis.git)

# %% [markdown]
# ##### Intro:
# We wil [working description...] analyze this data.
#
# The dataset used for this analysis is the 2014 Lahman Baseball Database (http://seanlahman.com/files/database/readme2014.txt), a Creative Commons licensed collection of various baseball statistics from the 1871 to 2014 seasons in the Major Leagues. From the 2014 readme on the design of the Lahman database:
#
# ```
# The database is comprised of the following main tables:
#
#   MASTER - Player names, DOB, and biographical info
#   Batting - batting statistics
#   Pitching - pitching statistics
#   Fielding - fielding statistics
#
# It is supplemented by these tables:
#
#   AllStarFull - All-Star appearances
#   HallofFame - Hall of Fame voting data
#   Managers - managerial statistics
#   Teams - yearly stats and standings
#   BattingPost - post-season batting statistics
#   PitchingPost - post-season pitching statistics
#   TeamFranchises - franchise information
#   FieldingOF - outfield position data
#   FieldingPost- post-season fieldinf data
#   ManagersHalf - split season data for managers
#   TeamsHalf - split season data for teams
#   Salaries - player salary data
#   SeriesPost - post-season series information
#   AwardsManagers - awards won by managers
#   AwardsPlayers - awards won by players
#   AwardsShareManagers - award voting for manager awards
#   AwardsSharePlayers - award voting for player awards
#   Appearances - details on the positions a player appeared at
#   Schools - list of colleges that players attended
#   CollegePlaying - list of players and the colleges they attended
# ```
#
# We begin by importing the libraries and doing a bit of housecleaning for plots.

# %%
# %pylab inline 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /Users/ben/anaconda/lib/python2.7/site-packages/matplotlib/__init__.py:872: UserWarning: axes.color_cycle is deprecated and replaced with axes.prop_cycle; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))

# %%
x = np.array([1,2,3,4,5,6,5,4,3,2,3,4])
plt.plot(x)
plt.scatter(x,x)
plt.hist(x,bins=6)
# Out:
# (array([ 1.,  2.,  3.,  3.,  2.,  1.]),
#  array([ 1.        ,  1.83333333,  2.66666667,  3.5       ,  4.33333333,
#          5.16666667,  6.        ]),
#  <a list of 6 Patch objects>)

# %%
dfMaster = pd.read_csv('MASTER.csv')
dfMaster.head()
# Out:
#     playerID  birthYear  birthMonth  birthDay birthCountry birthState  \
# 0  aardsda01       1981          12        27          USA         CO
# 1  aaronha01       1934           2         5          USA         AL
# 2  aaronto01       1939           8         5          USA         AL
# 3   aasedo01       1954           9         8          USA         CA
# 4   abadan01       1972           8        25          USA         FL
#
#     birthCity  deathYear  deathMonth  deathDay    ...     nameLast  \
# 0      Denver        NaN         NaN       NaN    ...      Aardsma
# 1      Mobile        NaN         NaN       NaN    ...        Aaron
# 2      Mobile       1984           8        16    ...        Aaron
# 3      Orange        NaN         NaN       NaN    ...         Aase
# 4  Palm Beach        NaN         NaN       NaN    ...         Abad
#
#         nameGiven weight height bats throws      debut  finalGame   retroID  \
# 0     David Allan    205     75    R      R   4/6/2004  9/28/2013  aardd001
# 1     Henry Louis    180     72    R      R  4/13/1954  10/3/1976  aaroh101
# 2      Tommie Lee    190     75    R      R  4/10/1962  9/26/1971  aarot101
# 3  Donald William    190     75    R      R  7/26/1977  10/3/1990  aased001
# 4   Fausto Andres    184     73    L      L  9/10/2001  4/13/2006  abada001
#
#      bbrefID
# 0  aardsda01
# 1  aaronha01
# 2  aaronto01
# 3   aasedo01
# 4   abadan01
#
# [5 rows x 24 columns]

# %%
dfBatting = pd.read_csv('Batting.csv')
dfBatting.head()
# Out:
#     playerID  yearID  stint teamID lgID   G   AB   R   H  2B  ...   RBI  SB  \
# 0  abercda01    1871      1    TRO  NaN   1    4   0   0   0  ...     0   0
# 1   addybo01    1871      1    RC1  NaN  25  118  30  32   6  ...    13   8
# 2  allisar01    1871      1    CL1  NaN  29  137  28  40   4  ...    19   3
# 3  allisdo01    1871      1    WS3  NaN  27  133  28  44  10  ...    27   1
# 4  ansonca01    1871      1    RC1  NaN  25  120  29  39  11  ...    16   6
#
#    CS  BB  SO  IBB  HBP  SH  SF  GIDP
# 0   0   0   0  NaN  NaN NaN NaN   NaN
# 1   1   4   0  NaN  NaN NaN NaN   NaN
# 2   1   2   5  NaN  NaN NaN NaN   NaN
# 3   1   0   2  NaN  NaN NaN NaN   NaN
# 4   2   2   1  NaN  NaN NaN NaN   NaN
#
# [5 rows x 22 columns]

# %%
dfMaster.loc[dfMaster['nameLast'].isin(['Jeter'])]
# Out:
#        playerID  birthYear  birthMonth  birthDay birthCountry birthState  \
# 8232  jeterde01       1974           6        26          USA         NJ
# 8233  jeterjo01       1944          10        24          USA         LA
# 8234  jetersh01       1966           6        28          USA         LA
#
#        birthCity  deathYear  deathMonth  deathDay    ...     nameLast  \
# 8232  Pequannock        NaN         NaN       NaN    ...        Jeter
# 8233  Shreveport        NaN         NaN       NaN    ...        Jeter
# 8234  Shreveport        NaN         NaN       NaN    ...        Jeter
#
#             nameGiven weight height bats throws      debut  finalGame  \
# 8232  Derek Sanderson    195     75    R      R  5/29/1995  9/28/2014
# 8233             John    180     73    R      R  6/14/1969  9/14/1974
# 8234    Shawn Darrell    185     74    L      R  6/13/1992  10/4/1992
#
#        retroID    bbrefID
# 8232  jeted001  jeterde01
# 8233  jetej101  jeterjo01
# 8234  jetes001  jetersh01
#
# [3 rows x 24 columns]

# %%
dfBatting.loc[dfBatting['playerID']=='jeterde01']
# Out:
#         playerID  yearID  stint teamID lgID    G   AB    R    H  2B  ...   \
# 73448  jeterde01    1995      1    NYA   AL   15   48    5   12   4  ...
# 74694  jeterde01    1996      1    NYA   AL  157  582  104  183  25  ...
# 75946  jeterde01    1997      1    NYA   AL  159  654  116  190  31  ...
# 77194  jeterde01    1998      1    NYA   AL  149  626  127  203  25  ...
# 78523  jeterde01    1999      1    NYA   AL  158  627  134  219  37  ...
# 79831  jeterde01    2000      1    NYA   AL  148  593  119  201  31  ...
# 81203  jeterde01    2001      1    NYA   AL  150  614  110  191  35  ...
# 82536  jeterde01    2002      1    NYA   AL  157  644  124  191  26  ...
# 83864  jeterde01    2003      1    NYA   AL  119  482   87  156  25  ...
# 85268  jeterde01    2004      1    NYA   AL  154  643  111  188  44  ...
# 86590  jeterde01    2005      1    NYA   AL  159  654  122  202  25  ...
# 87923  jeterde01    2006      1    NYA   AL  154  623  118  214  39  ...
# 89295  jeterde01    2007      1    NYA   AL  156  639  102  206  39  ...
# 90702  jeterde01    2008      1    NYA   AL  150  596   88  179  25  ...
# 92088  jeterde01    2009      1    NYA   AL  153  634  107  212  27  ...
# 93455  jeterde01    2010      1    NYA   AL  157  663  111  179  30  ...
# 94827  jeterde01    2011      1    NYA   AL  131  546   84  162  24  ...
# 96232  jeterde01    2012      1    NYA   AL  159  683   99  216  32  ...
# 97646  jeterde01    2013      1    NYA   AL   17   63    8   12   1  ...
# 99058  jeterde01    2014      1    NYA   AL  145  581   47  149  19  ...
#
#        RBI  SB  CS  BB   SO  IBB  HBP  SH  SF  GIDP
# 73448    7   0   0   3   11    0    0   0   0     0
# 74694   78  14   7  48  102    1    9   6   9    13
# 75946   70  23  12  74  125    0   10   8   2    14
# 77194   84  30   6  57  119    1    5   3   3    13
# 78523  102  19   8  91  116    5   12   3   6    12
# 79831   73  22   4  68   99    4   12   3   3    14
# 81203   74  27   3  56   99    3   10   5   1    13
# 82536   75  32   3  73  114    2    7   3   3    14
# 83864   52  11   5  43   88    2   13   3   1    10
# 85268   78  23   4  46   99    1   14  16   2    19
# 86590   70  14   5  77  117    3   11   7   3    15
# 87923   97  34   5  69  102    4   12   7   4    13
# 89295   73  15   8  56  100    3   14   3   2    21
# 90702   69  11   5  52   85    0    9   7   4    24
# 92088   66  30   5  72   90    4    5   4   1    18
# 93455   67  18   5  63  106    4    9   1   3    22
# 94827   61  16   6  46   81    0    6   4   5    10
# 96232   58   9   4  45   90    1    5   6   1    24
# 97646    7   0   0   8   10    1    1   0   1     3
# 99058   50  10   2  35   87    0    6   8   4    15
#
# [20 rows x 22 columns]
